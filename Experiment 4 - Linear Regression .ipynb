# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Datasets/Salary.csv')
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.shape
# Out:
# (35, 2)

# %%
x = df.iloc[:,:-1].values
y = df.iloc[:,1].values

plt.scatter(x,y, alpha=0.9,c=y,cmap='rainbow')

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5],
#        [11.2],
#        [11.5],
#        [12.3],
#        [12.9],
#        [13.5]])

# %%
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872, 127345, 126756,
#        128765, 135675, 139465], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 1/3)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([ 75829.85963718,  88665.46431341,  39890.16654371,  68984.20380985,
#         98078.24107599, 128883.69229896,  80964.10150767,  64705.66891777,
#        120326.6225148 , 112625.25970906,  43312.99445737,  65561.37589618])

# %%
y_test
# Out:
# array([ 83088,  91738,  39343,  61111, 101302, 126756,  81363,  55794,
#        121872, 112635,  37731,  57081], dtype=int64)

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train, regressor.predict(x_train), color='blue')
plt.title("Salary vs Experience (Training set)") # stating the title of the graph
 
plt.xlabel("Years of experience") # adding the name of x-axis
plt.ylabel("Salaries") # adding the name of y-axis
plt.show() # specifies end of graph

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train, regressor.predict(x_train), color='blue')
plt.title("Salary vs Experience (Testing set)") # stating the title of the graph
 
plt.xlabel("Years of experience") # adding the name of x-axis
plt.ylabel("Salaries") # adding the name of y-axis
plt.show() # specifies end of graph

# %%
from sklearn import metrics

meanAbErr = metrics.mean_absolute_error(y_test,y_pred)
meanSqErr = metrics.mean_squared_error(y_test,y_pred)
rootMeanSqErr = np.sqrt(meanSqErr)
print(f"R squared: {regressor.score(x,y) * 100} \nMean Absolute: {meanAbErr} \nMean Square: {meanSqErr} \nRoot Mean Square: {rootMeanSqErr}")
# Out:
# R squared: 96.45126128223342
# Mean Absolute: 4085.8794304775183
# Mean Square: 27030682.455317046
# Root Mean Square: 5199.104005049047
