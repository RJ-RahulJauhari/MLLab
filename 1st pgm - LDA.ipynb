# %%
import pandas as pd    #read csv files
import matplotlib.pyplot as plt 
import sklearn #preprocessing functions
from sklearn.preprocessing import StandardScaler, LabelEncoder 
from sklearn.model_selection import train_test_split 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
# read dataset from URL
url = "./Datasets/Iris.csv"
dataset = pd.read_csv(url)

# %%
print(dataset)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dataset.shape
# Out:
# (150, 6)

# %%
# divide the dataset into class and target variable
X = dataset.iloc[:, 1:5].values
y = dataset.iloc[:, -1].values #iloc extracts

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
# Preprocess the dataset and divide into train and test
sc = StandardScaler() #mean becomes 0 and std becomes 1
X = sc.fit_transform(X)
le = LabelEncoder()
y = le.fit_transform(y) #it assigns 0 1 and 2 for each class
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) # test_size=20% remaining train

# %%
X
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
# apply Linear Discriminant Analysis
lda = LinearDiscriminantAnalysis(n_components=2) # 4 features will be reduced to 2 # min(no.of features, no.of classes(3)-1)
X_train_Transformed = lda.fit_transform(X_train, y_train) 
# Applying the trained LDA model to the testing data
X_test_Transformed = lda.transform(X_test)

# %%
X_train_Transformed
# Out:
# array([[-7.60811430e+00, -1.76947209e+00],
#        [-2.05516931e+00, -1.71599973e-03],
#        [ 7.72985768e+00, -3.79124694e-01],
#        [ 6.75571973e+00,  6.95065389e-01],
#        [-8.23149300e-01, -1.42212898e-01],
#        [ 7.63920372e+00, -1.18240157e+00],
#        [-5.35420763e+00,  7.88301702e-01],
#        [ 6.50440580e+00,  7.25429828e-01],
#        [-1.84392184e+00, -2.29227369e-01],
#        [-2.80460471e+00, -2.00644767e-01],
#        [-7.01275070e+00,  5.87402260e-01],
#        [-5.87688985e+00, -6.05618667e-01],
#        [-8.43599496e+00,  8.73860671e-01],
#        [-1.71969429e+00,  1.15863250e+00],
#        [ 7.92607771e+00, -7.25596994e-01],
#        [-2.35697545e+00,  1.13425883e+00],
#        [-5.74371362e+00,  2.66558079e-02],
#        [ 6.95193976e+00,  3.48593089e-01],
#        [-3.13498866e+00,  1.50236279e-01],
#        [-1.83037147e+00,  4.36905485e-01],
#        [ 7.99816548e+00, -7.48188831e-01],
#        [-9.71735952e-01,  1.90473319e+00],
# ...

# %%
y_train
# Out:
# array([2, 1, 0, 0, 1, 0, 2, 0, 1, 1, 2, 2, 2, 1, 0, 1, 2, 0, 1, 1, 0, 1,
#        0, 0, 2, 2, 0, 2, 0, 2, 1, 1, 2, 0, 1, 1, 1, 2, 1, 2, 1, 0, 0, 0,
#        1, 2, 0, 1, 2, 0, 2, 0, 2, 2, 1, 0, 2, 0, 1, 1, 0, 2, 0, 0, 0, 2,
#        1, 0, 1, 0, 0, 1, 2, 2, 0, 2, 2, 1, 1, 1, 1, 0, 0, 0, 0, 1, 0, 0,
#        1, 1, 2, 1, 0, 1, 0, 0, 2, 2, 1, 2, 1, 2, 1, 1, 2, 0, 1, 1, 2, 2,
#        0, 2, 0, 0, 0, 2, 0, 0, 0, 1])

# %%
X_test_Transformed
# Out:
# array([[-7.60761598e+00, -2.49566661e+00],
#        [ 7.36442309e+00, -6.56547217e-02],
#        [-5.24048104e+00,  2.12742521e+00],
#        [-1.81536409e+00,  1.95619770e-01],
#        [-6.22139774e+00, -1.54616965e+00],
#        [-1.49489645e+00,  1.59725399e+00],
#        [-6.44855609e+00,  9.50985328e-02],
#        [ 7.60218665e+00, -7.62152015e-01],
#        [-1.47986902e+00,  1.71621492e+00],
#        [-3.09441277e+00,  7.97141151e-01],
#        [ 8.16531833e+00, -1.96926621e+00],
#        [-6.25332375e+00,  3.85309455e-01],
#        [-2.02159572e+00,  5.82866998e-01],
#        [-7.37780231e+00, -1.89730926e+00],
#        [-7.64560068e+00, -1.07848719e+00],
#        [-7.54997099e+00, -8.35967742e-01],
#        [-2.80903588e+00,  1.44087101e+00],
#        [ 7.26021874e+00, -1.53506445e+00],
#        [-6.09215436e+00,  1.42608246e-03],
#        [ 1.81138804e-01,  7.33259213e-01],
#        [-5.04830920e+00,  6.24287183e-01],
#        [ 7.21818585e+00, -1.27455075e+00],
# ...

# %%
# plot the scatterplot
plt.scatter(X_train_Transformed[:,0],X_train_Transformed[:,1],
            c=y_train,cmap='rainbow',
alpha=0.9,edgecolors='b')
plt.xlabel('LDA Component 1')
plt.ylabel('LDA Component 2')
plt.title('LDA Transformed Data (Training Set)')
plt.show()

# %%
# Plotting the transformed data for the testing set
plt.scatter(X_test_Transformed [:, 0], X_test_Transformed [:, 1], c=y_test,cmap='rainbow',
alpha=0.7,edgecolors='b')
plt.xlabel('LDA Component 1')
plt.ylabel('LDA Component 2')
plt.title('LDA Transformed Data (Testing Set)')
plt.show()

# %%
accuracy_train=lda.score(X_train, y_train)
print("Training Accuracy:", accuracy_train)
# Out:
# Training Accuracy: 0.9833333333333333

# %%
# Computing the accuracy of classification on the testing data
accuracy_test = lda.score(X_test, y_test)
print("Testing Accuracy:", accuracy_test)
# Out:
# Testing Accuracy: 0.9666666666666667
